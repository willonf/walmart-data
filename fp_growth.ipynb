# %%
from pyspark.sql import SparkSession, functions as f
from pyspark.ml.fpm import FPGrowth

# %%
spark = SparkSession.builder.appName('walmart-data').master('local').getOrCreate()

# %%
product_schema = 'product_id INT, product_name STRING, aisle_id INT, department_id INT'
order_product_schema = 'order_id INT, product_id INT, add_to_cart_order INT, reordered INT'

# %%
df_products = spark.read.option("header", True).schema(product_schema).csv('./datasets/products.csv').select('product_id')
df_products.show(5)
# Out:
# +----------+
# |product_id|
# +----------+
# |         1|
# |         2|
# |         3|
# |         4|
# |         5|
# +----------+

# %%
df_order_products = spark.read.option("header", True).schema(order_product_schema).csv(
    './datasets/order_products__prior.csv').drop("add_to_cart_order", "reordered").dropDuplicates()
df_order_products.show(5)
# Out:
# +--------+----------+
# |order_id|product_id|
# +--------+----------+
# |      27|     47766|
# |      83|     13292|
# |      93|     47226|
# |      95|     48287|
# |     106|     47144|
# +--------+----------+

# %%
df_transactions = df_order_products.groupBy('order_id').agg(f.collect_set('product_id').alias('items_transactions'))
df_transactions.show(truncate=False)
# Out:
# +--------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |order_id|items_transactions                                                                                                                                                                        |
# +--------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2       |[17794, 1819, 40141, 9327, 28985, 45918, 30035, 33120, 43668]                                                                                                                             |
# |3       |[32665, 33754, 17461, 17704, 21903, 17668, 24838, 46667]                                                                                                                                  |
# |4       |[32645, 46842, 21351, 17616, 27761, 26434, 34862, 39758, 22598, 25146, 40285, 41276, 10054]                                                                                               |
# |5       |[48370, 38693, 45698, 41176, 47209, 27966, 6348, 37011, 23909, 24773, 48002, 13245, 46522, 12962, 48366, 47329, 6184, 48825, 9633, 18569, 20914, 8479, 15005, 27360, 13176, 40878]        |
# |6       |[40462, 41897, 15873]                                                                                                                                                                     |
# |7       |[46802, 34050]                                                                                                                                                                            |
# |8       |[23423]                                                                                                                                                                                   |
# |9       |[31506, 23288, 14992, 18362, 11182, 2014, 432, 29193, 34203, 44533, 3990, 21405, 14183, 27366, 47890]                                                                                     |
# |10      |[47766, 14992, 25720, 3464, 31717, 4605, 24852, 22122, 49235, 1529, 26842, 4796, 21137, 27156, 34134]                                                                                     |
# |11      |[31506, 5994, 1313, 30162, 27085]                                                                                                                                                         |
# |12      |[23390, 25213, 11175, 37215, 38050, 43772, 15221, 29471, 34335, 3164, 30597, 43511, 26910, 37886, 38888]                                                                                  |
# |13      |[44635, 35419, 25783, 23020, 33198, 17330, 27407, 41290, 196, 26878, 36086, 3800, 25952]                                                                                                  |
# |14      |[41890, 45066, 20995, 8575, 23032, 39475, 27845, 2452, 10096, 162, 20392]                                                                                                                 |
# |15      |[21195, 2996, 7461, 19660, 32463]                                                                                                                                                         |
# |16      |[45437, 9755, 25466]                                                                                                                                                                      |
# |18      |[47766, 34969, 27966, 46979, 32018, 35547, 48745, 17568, 5212, 23339, 46969, 45495, 38985, 4656, 44632, 33279, 2116, 1057, 4802, 9848, 36011, 1000, 7308, 7948, 28934, 8021, 26648, 27644]|
# |19      |[42265, 41540, 24838]                                                                                                                                                                     |
# |20      |[35430, 5112, 27605, 33452, 47485, 24852, 42633, 7419]                                                                                                                                    |
# |21      |[33106, 31478, 25718, 4149, 5009]                                                                                                                                                         |
# |22      |[31268, 23341, 39993, 21410, 24852, 46941, 22754, 23909, 46979, 41273, 19068, 17341, 40593, 28993]                                                                                        |
# +--------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
min_support = 0.001
min_confidence= 0.001
fp = FPGrowth(minSupport=min_support, minConfidence=min_confidence, itemsCol='items_transactions')
model = fp.fit(df_transactions)
model.freqItemsets.show(truncate=False)
# Out:
# +--------------+----+
# |items         |freq|
# +--------------+----+
# |[46802]       |118 |
# |[46802, 27966]|16  |
# |[46802, 24489]|15  |
# |[46802, 47209]|20  |
# |[46802, 13176]|24  |
# |[46802, 21903]|29  |
# |[46802, 24852]|27  |
# |[32650]       |29  |
# |[31964]       |42  |
# |[27509]       |22  |
# |[13870]       |112 |
# |[13870, 21137]|20  |
# |[13870, 13176]|23  |
# |[13870, 24852]|28  |
# |[9741]        |29  |
# |[36316]       |42  |
# |[36316, 47977]|19  |
# |[28465]       |82  |
# |[28465, 24799]|27  |
# |[28465, 24852]|24  |
# +--------------+----+

# %%
model.associationRules.show()
# Out:
# +--------------+----------+-------------------+------------------+--------------------+
# |    antecedent|consequent|         confidence|              lift|             support|
# +--------------+----------+-------------------+------------------+--------------------+
# |       [43772]|   [13176]| 0.1485148514851485| 1.238368820159608|0.001002740824921452|
# |       [43772]|   [24852]|0.22772277227722773| 1.513329609282563|0.001537535931546...|
# |       [14084]|   [21137]|  0.189873417721519| 2.421412153193694|0.001002740824921452|
# |       [14084]|   [13176]|0.22784810126582278|1.8998772278904363|0.001203288989905...|
# |       [14084]|   [24852]|0.27848101265822783|1.8506430334759796|0.001470686543218...|
# |[39275, 24852]|   [27966]|0.23529411764705882| 5.456999544003648|0.001069590213249...|
# |[39275, 24852]|   [21137]|0.22058823529411764|2.8131111779750264|0.001002740824921452|
# |        [1463]|   [21137]|0.15447154471544716|1.9699401853353573|0.001270138378233839|
# |        [1463]|   [47209]|0.15447154471544716|2.3317253656895804|0.001270138378233839|
# |        [1463]|   [13176]| 0.2926829268292683|2.4404926992413736|0.002406577979811...|
# |        [1463]|   [27086]|0.14634146341463414|  6.27255573415333|0.001203288989905...|
# |        [1463]|   [21903]|0.12195121951219512|1.6782596988803373|0.001002740824921452|
# |        [1463]|   [24852]| 0.1951219512195122| 1.296681149841263|0.001604385319874323|
# |[34126, 24964]|   [22935]|             0.3125| 8.787006578947368|0.001002740824921452|
# |       [21292]|   [16797]|                0.3| 6.429369627507163|0.001203288989905...|
# |[40706, 27966]|   [21137]|0.39473684210526316| 5.033988423744784|0.001002740824921452|
# |[40706, 27966]|   [13176]|0.39473684210526316|3.2914539693715894|0.001002740824921452|
# |[24964, 21137]|   [13176]| 0.3246753246753247|2.7072565116043377|0.001671234708202...|
# |[24964, 21137]|   [24852]|0.23376623376623376| 1.553491377569565|0.001203288989905...|
# |[24964, 21137]|   [22935]|0.24675324675324675| 6.938311688311688|0.001270138378233839|
# +--------------+----------+-------------------+------------------+--------------------+

# %%
df_rules = model.associationRules.withColumn('conviction', (1-f.col('support'))/(1-f.col('confidence')))

# %%
df_rules.orderBy('conviction', ascending=False).show()
# Out:
# +--------------+----------+------------------+------------------+--------------------+------------------+
# |    antecedent|consequent|        confidence|              lift|             support|        conviction|
# +--------------+----------+------------------+------------------+--------------------+------------------+
# | [4962, 37718]|   [38544]|0.8823529411764706| 377.1176470588235|0.001002740824921452| 8.491476702988166|
# |[14947, 35221]|   [44632]|0.8095238095238095|32.036155202821874|0.001136439601577...| 5.244033692091718|
# | [4962, 38544]|   [37718]|              0.75|            320.55|0.001002740824921452| 3.995989036700314|
# |[37718, 38544]|    [4962]|0.7142857142857143|333.90625000000006|0.001002740824921452| 3.496490407112775|
# | [33787, 4957]|   [33754]|               0.7| 73.74154929577463|0.001403837154890...| 3.328653876150366|
# |[41787, 28204]|   [24852]|0.6896551724137931| 4.583097167542395|0.001336987766561...|3.2179141505299675|
# |[21709, 14947]|   [44632]|0.6818181818181818|26.982323232323232|0.001002740824921452|3.1397056716931036|
# |       [10768]|   [12745]|0.6538461538461539|238.55816135084427|0.001136439601577...| 2.885605841150998|
# |        [4962]|   [38544]|             0.625|           267.125|0.001336987766561...| 2.663101365955835|
# |[45066, 16797]|   [24852]|0.6052631578947368| 4.022270803619444|0.001537535931546...|2.5294382423067496|
# |[40571, 33754]|    [4957]|               0.6|  94.4778947368421|0.001002740824921452|2.4974931479376963|
# | [40571, 4957]|   [33754]|               0.6| 63.20704225352112|0.001002740824921452|2.4974931479376963|
# |       [38544]|   [37718]|               0.6|            256.44|0.001403837154890...|2.4964904071127747|
# |       [37718]|   [38544]|               0.6|            256.44|0.001403837154890...|2.4964904071127747|
# |[20114, 28842]|   [26209]|0.5925925925925926|13.872601866342084|0.001069590213249...|2.4519200967492965|
# | [8174, 27966]|   [13176]|0.5862068965517241| 4.887998308538038|0.001136439601577...| 2.413920270962854|
# |[19057, 47766]|   [13176]|0.5714285714285714| 4.764771460423634|0.001069590213249...| 2.330837622835751|
# |       [38544]|    [4962]|0.5714285714285714|           267.125|0.001336987766561...|2.3302136952113552|
# |[21709, 35221]|   [44632]|0.5714285714285714|22.613756613756614|0.001336987766561...|2.3302136952113552|
# | [4920, 49683]|   [24852]|0.5588235294117647|3.7136566754644993|0.001270138378233839|  2.26378768634267|
# +--------------+----------+------------------+------------------+--------------------+------------------+
